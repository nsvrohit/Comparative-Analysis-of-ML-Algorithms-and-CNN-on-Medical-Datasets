# %%
# Importing Support Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the Dataset
dataURL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data'
columnNames = ['ID', 'Diagnosis', 'MeanRadius', 'MeanTexture', 'MeanPerimeter', 'MeanArea', 'MeanSmoothness', 
               'MeanCompactness', 'MeanConcavity', 'MeanConcavePoints', 'MeanSymmetry', 'MeanFractalDimension', 
               'RadiusSE', 'TextureSE', 'PerimeterSE', 'AreaSE', 'SmoothnessSE', 'CompactnessSE', 'ConcavitySE', 
               'ConcavePointsSE', 'SymmetrySE', 'FractalDimensionSE', 'WorstRadius', 'WorstTexture', 
               'WorstPerimeter', 'WorstArea', 'WorstSmoothness', 'WorstCompactness', 'WorstConcavity', 
               'WorstConcavePoints', 'WorstSymmetry', 'WorstFractalDimension']
df = pd.read_csv(dataURL, header=None, names=columnNames)

# %%
df
# Out:
#            ID Diagnosis  MeanRadius  MeanTexture  MeanPerimeter  MeanArea  \
# 0      842302         M       17.99        10.38         122.80    1001.0
# 1      842517         M       20.57        17.77         132.90    1326.0
# 2    84300903         M       19.69        21.25         130.00    1203.0
# 3    84348301         M       11.42        20.38          77.58     386.1
# 4    84358402         M       20.29        14.34         135.10    1297.0
# ..        ...       ...         ...          ...            ...       ...
# 564    926424         M       21.56        22.39         142.00    1479.0
# 565    926682         M       20.13        28.25         131.20    1261.0
# 566    926954         M       16.60        28.08         108.30     858.1
# 567    927241         M       20.60        29.33         140.10    1265.0
# 568     92751         B        7.76        24.54          47.92     181.0
#
#      MeanSmoothness  MeanCompactness  MeanConcavity  MeanConcavePoints  ...  \
# ...

# %%
df = df.drop(['ID'], axis = 1)

# %%
df.isnull().sum()
# Out:
# Diagnosis                0
# MeanRadius               0
# MeanTexture              0
# MeanPerimeter            0
# MeanArea                 0
# MeanSmoothness           0
# MeanCompactness          0
# MeanConcavity            0
# MeanConcavePoints        0
# MeanSymmetry             0
# MeanFractalDimension     0
# RadiusSE                 0
# TextureSE                0
# PerimeterSE              0
# AreaSE                   0
# SmoothnessSE             0
# CompactnessSE            0
# ConcavitySE              0
# ConcavePointsSE          0
# SymmetrySE               0
# FractalDimensionSE       0
# WorstRadius              0
# WorstTexture             0
# WorstPerimeter           0
# WorstArea                0
# WorstSmoothness          0
# WorstCompactness         0
# WorstConcavity           0
# WorstConcavePoints       0
# WorstSymmetry            0
# WorstFractalDimension    0
# dtype: int64

# %%
df.describe()
# Out:
#        MeanRadius  MeanTexture  MeanPerimeter     MeanArea  MeanSmoothness  \
# count  569.000000   569.000000     569.000000   569.000000      569.000000
# mean    14.127292    19.289649      91.969033   654.889104        0.096360
# std      3.524049     4.301036      24.298981   351.914129        0.014064
# min      6.981000     9.710000      43.790000   143.500000        0.052630
# 25%     11.700000    16.170000      75.170000   420.300000        0.086370
# 50%     13.370000    18.840000      86.240000   551.100000        0.095870
# 75%     15.780000    21.800000     104.100000   782.700000        0.105300
# max     28.110000    39.280000     188.500000  2501.000000        0.163400
#
#        MeanCompactness  MeanConcavity  MeanConcavePoints  MeanSymmetry  \
# count       569.000000     569.000000         569.000000    569.000000
# mean          0.104341       0.088799           0.048919      0.181162
# std           0.052813       0.079720           0.038803      0.027414
# ...

# %%
radius = df[['MeanRadius','RadiusSE','WorstRadius','Diagnosis']]
sns.pairplot(radius, hue='Diagnosis')

# %%
texture = df[['MeanTexture','TextureSE','WorstTexture','Diagnosis']]
sns.pairplot(texture, hue='Diagnosis')

# %%
perimeter = df[['MeanPerimeter','PerimeterSE','WorstPerimeter','Diagnosis']]
sns.pairplot(perimeter, hue='Diagnosis')

# %%
area = df[['MeanArea','AreaSE','WorstArea','Diagnosis']]
sns.pairplot(area, hue='Diagnosis')

# %%
smoothness = df[['MeanSmoothness','SmoothnessSE','WorstSmoothness','Diagnosis']]
sns.pairplot(smoothness, hue='Diagnosis')

# %%
compactness = df[['MeanCompactness','CompactnessSE','WorstCompactness','Diagnosis']]
sns.pairplot(compactness, hue='Diagnosis')

# %%
concavity = df[['MeanConcavity','ConcavitySE','WorstConcavity','Diagnosis']]
sns.pairplot(concavity, hue='Diagnosis')

# %%
concavepoints = df[['MeanConcavePoints','ConcavePointsSE','WorstConcavePoints','Diagnosis']]
sns.pairplot(concavepoints, hue='Diagnosis')

# %%
symmetry = df[['MeanSymmetry','SymmetrySE','WorstSymmetry','Diagnosis']]
sns.pairplot(symmetry, hue='Diagnosis')

# %%
fractaldimension = df[['MeanFractalDimension','FractalDimensionSE','WorstFractalDimension','Diagnosis']]
sns.pairplot(fractaldimension, hue='Diagnosis')

# %%
pd.DataFrame(df['Diagnosis'].value_counts())
# Out:
#    Diagnosis
# B        357
# M        212

# %%
diagnosisCount = pd.DataFrame(df['Diagnosis'].value_counts())
diagnosisCount.plot(kind="barh")

# %%
for column in df.iloc[:,1:]:
    sns.distplot(df[column], hist = True, kde = True, kde_kws = {'shade': True, 'linewidth': 1})
    plt.xlabel(column)
    plt.ylabel('Density')
    plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot = True, cmap = "summer")

# %%
sns.heatmap(df.iloc[:,1:11].corr(), annot = True, cmap = "summer")

# %%
sns.heatmap(df.iloc[:,11:21].corr(), annot = True, cmap = "summer")

# %%
sns.heatmap(df.iloc[:,21:].corr(), annot = True, cmap = "summer")

# %%
df.iloc[:,1:].hist(figsize=(20,20))
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaleddf = scaler.fit_transform(df.iloc[:,1:])

# %%
scaleddf
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
sns.set(context='poster', style='whitegrid', rc={'figure.figsize':(20,20)})
sns.boxplot(data=df, orient='h')

# %%
sns.set(context='poster', style='whitegrid', rc={'figure.figsize':(20,20)})
sns.boxplot(data=scaleddf, orient='h')
